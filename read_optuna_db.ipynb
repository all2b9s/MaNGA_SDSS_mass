# %%
import optuna

# Load the study from the SQLite database
study = optuna.load_study(
    study_name="Mastar_no_u",  # Replace with your study name
    storage="sqlite:///Mastar_no_u.db"  # Replace with the path to your .db file
)

# Get the best trial
best_trial = study.best_trial

print(f"Best trial number: {best_trial.number}")
print(f"Best trial value: {best_trial.value}")
print("Best trial parameters:")
for key, value in best_trial.params.items():
    print(f"    {key}: {value}")
# Out:
# Best trial number: 67
# Best trial value: 0.062368087470531464
# Best trial parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 121
#     lr: 5.650400045777683e-05
#     weight_decay: 2.8232305430971988e-05

# %%
all_trials = study.trials

# Print details of each trial
for trial in all_trials:
    print(f"Trial number: {trial.number}")
    print(f"Value: {trial.value}")
    print("Parameters:")
    for key, value in trial.params.items():
        print(f"    {key}: {value}")
    print(f"State: {trial.state}")
    print("-" * 40)
# Out:
# Trial number: 0
# Value: 0.3257971405982971
# Parameters:
#     num_layers: 5
#     kernels_size/2: 5
#     num_filters: 113
#     lr: 1.1941344425594402e-05
#     weight_decay: 2.2696232927012646e-06
# State: 1
# ----------------------------------------
# Trial number: 1
# Value: 0.14726783335208893
# Parameters:
#     num_layers: 4
#     kernels_size/2: 4
#     num_filters: 32
#     lr: 1.7934474528915116e-05
#     weight_decay: 2.6438769913900873e-05
# State: 1
# ----------------------------------------
# Trial number: 2
# Value: 0.36396536231040955
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 81
#     lr: 2.087351459332e-06
#     weight_decay: 2.0886673872618262e-05
# State: 1
# ----------------------------------------
# Trial number: 3
# Value: 0.11959075182676315
# Parameters:
#     num_layers: 4
#     kernels_size/2: 4
#     num_filters: 66
#     lr: 1.2019546078799378e-05
#     weight_decay: 2.0386003908384667e-06
# State: 1
# ----------------------------------------
# Trial number: 4
# Value: 66.53768157958984
# Parameters:
#     num_layers: 3
#     kernels_size/2: 0
#     num_filters: 65
#     lr: 1.2366353871859256e-05
#     weight_decay: 1.5408871852456738e-05
# State: 1
# ----------------------------------------
# Trial number: 5
# Value: 0.32909083366394043
# Parameters:
#     num_layers: 5
#     kernels_size/2: 2
#     num_filters: 57
#     lr: 4.0058750935689675e-06
#     weight_decay: 8.652957273354189e-05
# State: 1
# ----------------------------------------
# Trial number: 6
# Value: 0.3915751576423645
# Parameters:
#     num_layers: 5
#     kernels_size/2: 1
#     num_filters: 36
#     lr: 9.56318802528489e-06
#     weight_decay: 6.98783189660348e-06
# State: 1
# ----------------------------------------
# Trial number: 7
# Value: 66.36860656738281
# Parameters:
#     num_layers: 4
#     kernels_size/2: 0
#     num_filters: 101
#     lr: 8.557498331117776e-06
#     weight_decay: 6.351593339748634e-05
# State: 1
# ----------------------------------------
# Trial number: 8
# Value: 2.4753546714782715
# Parameters:
#     num_layers: 3
#     kernels_size/2: 1
#     num_filters: 46
#     lr: 1.7135367010743716e-06
#     weight_decay: 1.5949382200432352e-06
# State: 1
# ----------------------------------------
# Trial number: 9
# Value: 0.12754051387310028
# Parameters:
#     num_layers: 3
#     kernels_size/2: 5
#     num_filters: 38
#     lr: 1.3233057608583302e-05
#     weight_decay: 6.996863579506967e-05
# State: 1
# ----------------------------------------
# Trial number: 10
# Value: 1.2367359399795532
# Parameters:
#     num_layers: 5
#     kernels_size/2: 0
#     num_filters: 104
#     lr: 8.042686966398877e-06
#     weight_decay: 5.3558151578664325e-05
# State: 1
# ----------------------------------------
# Trial number: 11
# Value: 0.09884350001811981
# Parameters:
#     num_layers: 4
#     kernels_size/2: 3
#     num_filters: 42
#     lr: 2.8598796531526517e-05
#     weight_decay: 1.6219673019788302e-06
# State: 1
# ----------------------------------------
# Trial number: 12
# Value: 0.37697654962539673
# Parameters:
#     num_layers: 5
#     kernels_size/2: 5
#     num_filters: 57
#     lr: 1.0006580021719768e-05
#     weight_decay: 6.472816238746135e-05
# State: 1
# ----------------------------------------
# Trial number: 13
# Value: 0.23459658026695251
# Parameters:
#     num_layers: 5
#     kernels_size/2: 3
#     num_filters: 44
#     lr: 8.303085238029353e-05
#     weight_decay: 1.5488989714171437e-06
# State: 1
# ----------------------------------------
# Trial number: 14
# Value: 0.2800440788269043
# Parameters:
#     num_layers: 3
#     kernels_size/2: 2
#     num_filters: 36
#     lr: 5.979440556214759e-06
#     weight_decay: 9.721605162703843e-05
# State: 1
# ----------------------------------------
# Trial number: 15
# Value: 0.3250613212585449
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 56
#     lr: 6.358955779921892e-06
#     weight_decay: 1.3947259737683796e-05
# State: 1
# ----------------------------------------
# Trial number: 16
# Value: 0.15103845298290253
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 40
#     lr: 9.125187220131491e-06
#     weight_decay: 3.514856089780352e-05
# State: 1
# ----------------------------------------
# Trial number: 17
# Value: 2.959669589996338
# Parameters:
#     num_layers: 3
#     kernels_size/2: 1
#     num_filters: 49
#     lr: 3.3128556352174594e-06
#     weight_decay: 3.315326224815817e-05
# State: 1
# ----------------------------------------
# Trial number: 18
# Value: 66.54525756835938
# Parameters:
#     num_layers: 5
#     kernels_size/2: 0
#     num_filters: 109
#     lr: 5.813992644128356e-06
#     weight_decay: 8.208277496857928e-05
# State: 1
# ----------------------------------------
# Trial number: 19
# Value: 0.7149895429611206
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 58
#     lr: 3.953178010696359e-06
#     weight_decay: 3.9550167361174363e-05
# State: 1
# ----------------------------------------
# Trial number: 20
# Value: 0.4776180386543274
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 44
#     lr: 2.275847057723842e-06
#     weight_decay: 3.0181629789810064e-06
# State: 1
# ----------------------------------------
# Trial number: 21
# Value: 0.1110038086771965
# Parameters:
#     num_layers: 4
#     kernels_size/2: 5
#     num_filters: 70
#     lr: 2.7345478684736746e-05
#     weight_decay: 2.667152020490356e-05
# State: 1
# ----------------------------------------
# Trial number: 22
# Value: 0.39096081256866455
# Parameters:
#     num_layers: 5
#     kernels_size/2: 5
#     num_filters: 104
#     lr: 1.4746278162615332e-06
#     weight_decay: 3.209501092766515e-05
# State: 1
# ----------------------------------------
# Trial number: 23
# Value: 0.3293542265892029
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 43
#     lr: 8.156147214548407e-06
#     weight_decay: 7.568327878042503e-06
# State: 1
# ----------------------------------------
# Trial number: 24
# Value: 0.09053155034780502
# Parameters:
#     num_layers: 4
#     kernels_size/2: 3
#     num_filters: 51
#     lr: 4.177802612924498e-05
#     weight_decay: 2.5371957206918053e-05
# State: 1
# ----------------------------------------
# Trial number: 25
# Value: 0.8128259181976318
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 32
#     lr: 1.2946302196279005e-06
#     weight_decay: 2.388116706486201e-06
# State: 1
# ----------------------------------------
# Trial number: 26
# Value: 0.10844655334949493
# Parameters:
#     num_layers: 3
#     kernels_size/2: 4
#     num_filters: 34
#     lr: 3.363254304776757e-05
#     weight_decay: 9.078318258542775e-06
# State: 1
# ----------------------------------------
# Trial number: 27
# Value: 0.17971783876419067
# Parameters:
#     num_layers: 4
#     kernels_size/2: 4
#     num_filters: 77
#     lr: 6.60275132939348e-06
#     weight_decay: 3.3675438590956575e-05
# State: 1
# ----------------------------------------
# Trial number: 28
# Value: 0.08826959878206253
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 128
#     lr: 8.144806677769667e-06
#     weight_decay: 1.2512618424890424e-05
# State: 1
# ----------------------------------------
# Trial number: 29
# Value: 1.4415779113769531
# Parameters:
#     num_layers: 3
#     kernels_size/2: 1
#     num_filters: 66
#     lr: 2.0465427731788564e-06
#     weight_decay: 2.1379045454845987e-06
# State: 1
# ----------------------------------------
# Trial number: 30
# Value: 0.23899394273757935
# Parameters:
#     num_layers: 4
#     kernels_size/2: 5
#     num_filters: 40
#     lr: 9.09506067427753e-06
#     weight_decay: 5.211675270564426e-06
# State: 1
# ----------------------------------------
# Trial number: 31
# Value: 1.3187155723571777
# Parameters:
#     num_layers: 3
#     kernels_size/2: 2
#     num_filters: 36
#     lr: 1.9122123508007326e-06
#     weight_decay: 1.5729916880041474e-06
# State: 1
# ----------------------------------------
# Trial number: 32
# Value: 0.16190874576568604
# Parameters:
#     num_layers: 4
#     kernels_size/2: 4
#     num_filters: 52
#     lr: 1.0526337600232826e-05
#     weight_decay: 1.043678808054479e-06
# State: 1
# ----------------------------------------
# Trial number: 33
# Value: 33.46266174316406
# Parameters:
#     num_layers: 4
#     kernels_size/2: 0
#     num_filters: 117
#     lr: 1.0006207429093732e-06
#     weight_decay: 2.0275335778954076e-06
# State: 1
# ----------------------------------------
# Trial number: 34
# Value: 0.29507771134376526
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 93
#     lr: 1.594134749793606e-06
#     weight_decay: 4.067980316461974e-05
# State: 1
# ----------------------------------------
# Trial number: 35
# Value: 0.10753363370895386
# Parameters:
#     num_layers: 3
#     kernels_size/2: 4
#     num_filters: 95
#     lr: 5.086942843325213e-05
#     weight_decay: 4.9606434821235115e-05
# State: 1
# ----------------------------------------
# Trial number: 36
# Value: 0.39332595467567444
# Parameters:
#     num_layers: 3
#     kernels_size/2: 3
#     num_filters: 48
#     lr: 2.209666870173524e-06
#     weight_decay: 6.529473329298641e-06
# State: 1
# ----------------------------------------
# Trial number: 37
# Value: 66.30610656738281
# Parameters:
#     num_layers: 5
#     kernels_size/2: 4
#     num_filters: 54
#     lr: 8.450462709647231e-05
#     weight_decay: 1.1450443746195147e-06
# State: 1
# ----------------------------------------
# Trial number: 38
# Value: 0.20342011749744415
# Parameters:
#     num_layers: 5
#     kernels_size/2: 3
#     num_filters: 50
#     lr: 1.267948201905372e-05
#     weight_decay: 2.910803426802496e-05
# State: 1
# ----------------------------------------
# Trial number: 39
# Value: 0.09853462874889374
# Parameters:
#     num_layers: 3
#     kernels_size/2: 1
#     num_filters: 53
#     lr: 1.92502209601415e-05
#     weight_decay: 4.8274545754842955e-05
# State: 1
# ----------------------------------------
# Trial number: 40
# Value: 0.07656407356262207
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 126
#     lr: 1.841592949782638e-05
#     weight_decay: 1.3894145242347877e-05
# State: 1
# ----------------------------------------
# Trial number: 41
# Value: 0.08180132508277893
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 128
#     lr: 2.1964172684784598e-05
#     weight_decay: 1.9084676077656002e-05
# State: 1
# ----------------------------------------
# Trial number: 42
# Value: 0.07949849963188171
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 128
#     lr: 1.834420253228741e-05
#     weight_decay: 1.961066346757567e-05
# State: 1
# ----------------------------------------
# Trial number: 43
# Value: 0.07533013075590134
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 128
#     lr: 1.8223746911716238e-05
#     weight_decay: 1.99883842190668e-05
# State: 1
# ----------------------------------------
# Trial number: 44
# Value: 0.07363311201334
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 127
#     lr: 1.6335894329274938e-05
#     weight_decay: 1.665300116583043e-05
# State: 1
# ----------------------------------------
# Trial number: 45
# Value: 0.07649796456098557
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 127
#     lr: 1.6932748116664263e-05
#     weight_decay: 1.860064220985835e-05
# State: 1
# ----------------------------------------
# Trial number: 46
# Value: 0.07205560058355331
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 118
#     lr: 1.5297086718007635e-05
#     weight_decay: 1.9009577372331556e-05
# State: 1
# ----------------------------------------
# Trial number: 47
# Value: 0.07502388954162598
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 118
#     lr: 1.437401772039866e-05
#     weight_decay: 1.6529288078007867e-05
# State: 1
# ----------------------------------------
# Trial number: 48
# Value: 0.07176094502210617
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 117
#     lr: 1.5050863479931979e-05
#     weight_decay: 1.6400844659341215e-05
# State: 1
# ----------------------------------------
# Trial number: 49
# Value: 0.07116593420505524
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 115
#     lr: 2.367171175543105e-05
#     weight_decay: 1.1756350964722425e-05
# State: 1
# ----------------------------------------
# Trial number: 50
# Value: 0.07528478652238846
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 117
#     lr: 1.356521082381444e-05
#     weight_decay: 1.0763363771927535e-05
# State: 1
# ----------------------------------------
# Trial number: 51
# Value: 0.07458630204200745
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 115
#     lr: 1.2836257591660118e-05
#     weight_decay: 1.1609526060750811e-05
# State: 1
# ----------------------------------------
# Trial number: 52
# Value: 0.07310038805007935
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 112
#     lr: 1.5013645970146612e-05
#     weight_decay: 1.6060044307539197e-05
# State: 1
# ----------------------------------------
# Trial number: 53
# Value: 0.08746408671140671
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 97
#     lr: 2.4361545307258468e-05
#     weight_decay: 1.0108191735103957e-05
# State: 1
# ----------------------------------------
# Trial number: 54
# Value: 0.07473811507225037
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 109
#     lr: 1.507502075844526e-05
#     weight_decay: 2.3973579675135183e-05
# State: 1
# ----------------------------------------
# Trial number: 55
# Value: 0.07938601821660995
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 86
#     lr: 2.3403456960190078e-05
#     weight_decay: 1.2772410930736866e-05
# State: 1
# ----------------------------------------
# Trial number: 56
# Value: 0.07502786815166473
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 113
#     lr: 1.1282579825369612e-05
#     weight_decay: 4.78152344538234e-06
# State: 1
# ----------------------------------------
# Trial number: 57
# Value: 0.08161649852991104
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 88
#     lr: 3.904838829932275e-05
#     weight_decay: 1.600335559957719e-05
# State: 1
# ----------------------------------------
# Trial number: 58
# Value: 0.09619896113872528
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 100
#     lr: 1.5787012798647413e-05
#     weight_decay: 8.319499291507725e-06
# State: 1
# ----------------------------------------
# Trial number: 59
# Value: 0.07345198094844818
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 108
#     lr: 2.6574522123105127e-05
#     weight_decay: 1.1950290498444663e-05
# State: 1
# ----------------------------------------
# Trial number: 60
# Value: 0.07269567251205444
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 108
#     lr: 5.489874924221397e-05
#     weight_decay: 2.2835278093256865e-05
# State: 1
# ----------------------------------------
# Trial number: 61
# Value: 0.06374084949493408
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 108
#     lr: 6.810635040181332e-05
#     weight_decay: 1.5734580658799884e-05
# State: 1
# ----------------------------------------
# Trial number: 62
# Value: 0.06594401597976685
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 107
#     lr: 6.979545725099667e-05
#     weight_decay: 2.2503055256440965e-05
# State: 1
# ----------------------------------------
# Trial number: 63
# Value: 0.07222237437963486
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 104
#     lr: 6.669222908617648e-05
#     weight_decay: 2.192027566659788e-05
# State: 1
# ----------------------------------------
# Trial number: 64
# Value: 66.8055419921875
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 104
#     lr: 7.168174239915004e-05
#     weight_decay: 2.460785655631044e-05
# State: 1
# ----------------------------------------
# Trial number: 65
# Value: 0.0694810152053833
# Parameters:
#     num_layers: 4
#     kernels_size/2: 2
#     num_filters: 120
#     lr: 6.33303491082611e-05
#     weight_decay: 2.2348663047436478e-05
# State: 1
# ----------------------------------------
# Trial number: 66
# Value: 0.07193008065223694
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 121
#     lr: 6.867535523311983e-05
#     weight_decay: 2.9908311150029172e-05
# State: 1
# ----------------------------------------
# Trial number: 67
# Value: 0.062368087470531464
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 121
#     lr: 5.650400045777683e-05
#     weight_decay: 2.8232305430971988e-05
# State: 1
# ----------------------------------------
# Trial number: 68
# Value: 0.06685668975114822
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 121
#     lr: 9.915702454853492e-05
#     weight_decay: 2.9882105766153003e-05
# State: 1
# ----------------------------------------
# Trial number: 69
# Value: 66.6978759765625
# Parameters:
#     num_layers: 4
#     kernels_size/2: 0
#     num_filters: 100
#     lr: 9.53881548234372e-05
#     weight_decay: 3.773637309308927e-05
# State: 1
# ----------------------------------------
# Trial number: 70
# Value: 0.06681264936923981
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 122
#     lr: 5.447640448151873e-05
#     weight_decay: 2.8217043073596584e-05
# State: 1
# ----------------------------------------
# Trial number: 71
# Value: 0.06482730060815811
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 122
#     lr: 5.557342532825582e-05
#     weight_decay: 4.408093749725512e-05
# State: 1
# ----------------------------------------
# Trial number: 72
# Value: 0.07589508593082428
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 121
#     lr: 5.143814964371706e-05
#     weight_decay: 4.50418701066633e-05
# State: 1
# ----------------------------------------
# Trial number: 73
# Value: None
# Parameters:
#     num_layers: 4
#     kernels_size/2: 1
#     num_filters: 122
#     lr: 6.202103789455923e-05
#     weight_decay: 6.167391757535251e-05
# State: 0
# ----------------------------------------
